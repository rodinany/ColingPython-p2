# %%
import pandas as pd

# %%
df = pd.read_csv("eda.csv")

# %%
df.sample(3)
# Out:
#                                          id  \
# 854    a68011b8-c3f0-11ea-b344-0242ac1c0002
# 2599   5a842e68-c3f8-11ea-b8df-0242ac1c0002
# 25437  c4c140f0-c474-11ea-ba01-ac1f6b2cd28a
#
#                                                    name  \
# 854    Рулетики из фарша с грибами, запеченные в беконе
# 2599                              Тефтели по‑югославски
# 25437                                Хворост с коньяком
#
#                                              list_ingrid  \
# 854    Свежая кинза (кориандр) Яйцо куриное Панировоч...
# 2599   Баранина Яйцо куриное Яичный желток Пшеничная ...
# 25437  Пшеничная мука 2,5 стакана Яичный желток 3 шту...
#
#                                                image_url  \
# 854    eda.ru/img/eda/-x900i/s1.eda.ru/StaticContent/...
# 2599   eda.ru/img/eda/-x900i/s2.eda.ru/StaticContent/...
# 25437  eda.ru/img/eda/-x900i/s2.eda.ru/StaticContent/...
#
#                                              list_resipe  \
# ...

# %% [markdown]
# # GET query recipes by substring
# Необходимо реализовать метод get
#
# /recipes/?query=`substring`
#
# где subtring - пользовательский параметр
#
# возвращает json вида:
#
#     [
#         {"id": ,
#          "name": },
#         .
#         .
#     ]
# Каждый элемент - возможный рецепт

# %% [markdown]
# # GET recipe by id
#
# Необходимо реализовать метод get
#
# /recipes/{id}
#
# где id - поле id в датафрейме
#
# возвращает json вида:
#
#     {
#         "id": ,
#         "name": ,
#         "ingredients": ,
#         "recipe": ,
#         "img_url": ,
#         "nutrition_info": {
#                "callories": ,
#                "proteins": ,
#                "carbs":
#             }
#         "recipe_url": ,
#         "likes":
#     }

# %% [markdown]
# # GET lucky
#
# Необходимо реализовать метод get random recipe, возвращающий случайный рецепт
#
# /recipes/random
#
# возвращает json вида:
#
#     {
#         "id": ,
#         "name": ,
#         "ingredients": ,
#         "recipe": ,
#         "img_url": ,
#         "nutrition_info": {
#                "callories": ,
#                "proteins": ,
#                "carbs":
#             }
#         "recipe_url": ,
#         "likes":
#     }

# %% [markdown]
# # GET recipes by calories
#
# Реализовать метод get, возвращающий `topn` рецептов, не превышающих `cal` калорий в порядке возрастания
#
# /recipes/diet/?calories=`cal`&topn=`topn`
#
#     [
#         {"id": ,
#          "name": ,
#          "nutritiion_info":
#              {...}
#         },
#         .
#         .
#     ]

# %% [markdown]
# # GET top simple or simple recipes
#
# /recipes/?difficulty=`hard`|`simple`&topn=`topn`
#
# Реализовать метод get, возвращающий topn сложных или topn простых рецептов (расчитайте сложность по предложенной вами формуле)
#
# возвращает json вида:
#
#     [
#         {"id": ,
#          "name": ,
#          "difficulty": },
#         .
#         .
#     ]

# %% [markdown]
# # PUT recipe
#
# /recipes/new
#
# отправляем json body вида:
#
#     {
#         "id": ,
#         "name": ,
#         "ingredients": ,
#         "recipe": ,
#         "img_url": ,
#         "nutrition_info": {
#                "callories": ,
#                "proteins": ,
#                "carbs":
#             }
#         "recipe_url":
#     }
#
#
# Получаем `201`

# %% [markdown]
# # POST find 5 recipes by ingredients
#
# /recipes/search
#
# Отправляем body:
#
#     {"ingredients": []}
#
# Получаем:
#
#     [
#     {"id": ,
#      "name": ,
#      "ingredients": },
#     .
#     .
#     ]
